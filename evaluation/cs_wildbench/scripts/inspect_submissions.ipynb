# %%
import json 

with open("/home/mlynatom/master-thesis-repository-tomas-mlynar/wildbench_result_dirs/v2.0522/pairwise.v2/eval=gpt-4-turbo-2024-04-09/ref=B+IT/B+IT->IT_(cs+en).batch-submit.jsonl", "r") as f:
    lines = f.readlines()
    
    data = json.loads(lines[5])
    print(data["body"]["messages"][0]["content"])
# Out:
# # Instrukce
#
# Jsi odborný hodnotitel. Tvým úkolem je posoudit kvalitu odpovědí generovaných dvěma AI modely.
# Poskytneme ti uživatelský dotaz a dvojici AI-generovaných odpovědí (Odpověď A a Odpověď B).
# Nejprve si pečlivě přečti uživatelský dotaz a historii konverzace, abys správně analyzoval úkol, a poté vyhodnoť kvalitu odpovědí na základě pravidel uvedených níže.
#
# # Konverzace mezi uživatelem a AI
#
# ## Historie
# <|begin_of_history|>
#
#
#
# <|end_of_history|>
#
# ## Aktuální uživatelský dotaz
# <|begin_of_query|>
#
# ahoj vytvor mi esej z ceske ustavy
#
# <|end_of_query|>
#
# ## Odpověď A
# <|begin_of_response_A|>
#
# Dobrý den! Rád bych vám pomohl s vytvořením eseje z češtiny. Předpokládám, že máte na mysli nějaký konkrétní úkol nebo téma, o kterém byste chtěl psát. Pokud ano, prosím, sdělte mi, o čem by esej měla být.
#
# Pokud máte nějaké konkrétní požadavky nebo omezení, jako je délka, styl nebo téma, prosím, sdělte mi to také.
#
# ...
