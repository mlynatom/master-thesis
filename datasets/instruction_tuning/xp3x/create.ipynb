# %%
# %pip install git+https://github.com/Muennighoff/promptsource.git@xp3x
# Out:
# ...
#   Cloning https://github.com/Muennighoff/promptsource.git (to revision xp3x) to /data/temporary/pip-req-build-142c_g2t
# ...
#   Using cached black-21.12b0-py3-none-any.whl (156 kB)
# ...
#      |████████████████████████████████| 480 kB 9.8 MB/s eta 0:00:01
# ...
#   Using cached flake8-7.1.1-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached isort-5.8.0-py3-none-any.whl (103 kB)
# ...
#   Using cached pytest-8.3.4-py3-none-any.whl (343 kB)
# ...
#   Using cached streamlit-0.82.0-py2.py3-none-any.whl (8.2 MB)
# ...
#   Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# ...
#      |████████████████████████████████| 12.4 MB 75.7 MB/s eta 0:00:01
# ...
#   Using cached py7zr-0.22.0-py3-none-any.whl (67 kB)
# ...
#      |████████████████████████████████| 98 kB 8.0 MB/s  eta 0:00:01
# ...
#   Using cached tomli-1.2.3-py3-none-any.whl (12 kB)
# ...
#      |████████████████████████████████| 194 kB 27.9 MB/s eta 0:00:01
# ...
#   Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# ...
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# ...

# %%
# %pip install datasets iso-639
# Out:
# ...
#      |████████████████████████████████| 167 kB 9.9 MB/s eta 0:00:01
# ...
# Using legacy 'setup.py install' for iso-639, since package 'wheel' is not installed.
# ...
#     Running setup.py install for iso-639 ... done
# ...
# WARNING: You are using pip version 20.2.1; however, version 25.0 is available.
# You should consider upgrading via the '/home/mlynatom/master-thesis-repository-tomas-mlynar/venv/xp3x/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipywidgets
# Out:
# ...
#      |████████████████████████████████| 139 kB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 214 kB 95.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.3 MB 127.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.1; however, version 25.0 is available.
# You should consider upgrading via the '/home/mlynatom/master-thesis-repository-tomas-mlynar/venv/xp3x/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run ./datasets/instruction_tuning/xp3x/create_xp3x.py
# Out:
# TRAIN_DATASETS [('Muennighoff/mbpp', 'sanitized'), ('great_code', None), ('neural_code_search', 'evaluation_dataset'), ('codeparrot/codecomplex', 'codeparrot--codecomplex'), ('codeparrot/github-jupyter-text-code-pairs', None), ('codeparrot/apps', 'all'), ('codeparrot/xlcost-text-to-code', 'Python-program-level'), ('codeparrot/xlcost-text-to-code', 'C-program-level'), ('codeparrot/xlcost-text-to-code', 'C++-program-level'), ('codeparrot/xlcost-text-to-code', 'Csharp-program-level'), ('codeparrot/xlcost-text-to-code', 'Java-program-level'), ('codeparrot/xlcost-text-to-code', 'Javascript-program-level'), ('codeparrot/xlcost-text-to-code', 'PHP-program-level'), ('teven/code_contests', None), ('teven/code_docstring_corpus', 'top_level'), ('Fraser/python-state-changes', None), ('clue', 'c3'), ('clue', 'cmrc2018'), ('clue', 'csl'), ('clue', 'drcd'), ('clue', 'tnews'), ('glue', 'mrpc'), ('glue', 'qqp'), ('paws', 'labeled_final'), ('ai2_arc', 'ARC-Challenge'), ('ai2_arc', 'ARC-Easy'), ('kilt_
# ...
