# %% [markdown]
# # Vocabulary (Tokenizer) Extension/Expansion/Adaptation

# %% [markdown]
# ## Prepare Data

# %%
from datasets import load_dataset

# this dataset has already fixed encoding using ftfy (as is used by me in the preprocessing steps of other datasets)
dataset = load_dataset("HuggingFaceFW/fineweb-2", "ces_Latn", split="train", streaming=True)
dataset
# Out:
# Resolving data files:   0%|          | 0/25 [00:00<?, ?it/s]
# IterableDataset({
#     features: ['text', 'id', 'dump', 'url', 'date', 'file_path', 'language', 'language_score', 'language_script', 'minhash_cluster_size', 'top_langs'],
#     n_shards: 25
# })

# %%
#we need only texts
dataset = dataset.remove_columns(["id", "dump", "url", "date", "file_path", "language", "language_score", "language_script", "minhash_cluster_size", "top_langs"])
dataset
# Out:
# IterableDataset({
#     features: ['text'],
#     n_shards: 25
# })

# %%
#shuffle to be sure we select "random sample"
dataset = dataset.shuffle(seed=42, buffer_size=10000)

# %%
#limit the number of samples
dataset = dataset.take(100000)
dataset
# Out:
# IterableDataset({
#     features: ['text'],
#     n_shards: 25
# })

# %%
#prepare iterator that outputs only texts
def serve_texts():
    for example in dataset:
        yield example["text"]

# %% [markdown]
# ## Load the Original Tokenizer

# %%
from transformers import AutoTokenizer

old_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-3B-Instruct")

# %%
example = "Řeřicha je květina vyskutjící se v Česku a na Moravě."
old_tokenizer.tokenize(example)
# Out:
# ['Åĺ',
#  'e',
#  'ÅĻ',
#  'icha',
#  'Ġje',
#  'ĠkvÄĽt',
#  'ina',
#  'Ġvys',
#  'k',
#  'ut',
#  'jÃŃcÃŃ',
#  'Ġse',
#  'Ġv',
#  'ĠÄĮes',
#  'ku',
#  'Ġa',
#  'Ġna',
#  'ĠMor',
#  'avÄĽ',
#  '.']

# %% [markdown]
# ## Train new Tokenizer

# %%
#25000 based on the SambaLingo paper
tokenizer = old_tokenizer.train_new_from_iterator(serve_texts(), 25000)

# %%
tokenizer.tokenize(example)
# Out:
# ['Åĺe',
#  'ÅĻi',
#  'cha',
#  'Ġje',
#  'ĠkvÄĽt',
#  'ina',
#  'Ġvy',
#  'sku',
#  't',
#  'jÃŃcÃŃ',
#  'Ġse',
#  'Ġv',
#  'ĠÄĮesku',
#  'Ġa',
#  'Ġna',
#  'ĠMoravÄĽ',
#  '.']

# %% [markdown]
# ## Tokenizer Merging

# %%
old_tokenizer.vocab_size, tokenizer.vocab_size
# Out:
# (128000, 25000)

# %%
old_vocab = set(old_tokenizer.get_vocab())
new_vocab = set(tokenizer.get_vocab())


diff_vocab = new_vocab - old_vocab
diff_vocab, len(diff_vocab)
# Out:
# ({'Ġnasy',
#   'Ġvstupenky',
#   'ÅĻadu',
#   'Ġvce',
#   'teÄįnÃ½m',
#   'Ġdezer',
#   'ĠaÄį',
#   'ĠpÅĻedstaven',
#   'spod',
#   'ĠudÄĽlala',
#   'venÃŃ',
#   'ĠpÄĽknÄĽ',
#   'ĠdÃŃlny',
#   'hovÃ©',
#   'ĠDisku',
#   'ĠtÄĽÅ¾kÃ¡',
#   'ĠstÅĻihu',
#   'Ġpum',
#   'ĠsouÄįasnÄĽ',
#   'ĠdobrÃ½m',
#   '|Hmotnost',
#   'Ġkoru',
#   'Ġosoba',
#   'Ġspustit',
#   'ĠÄįernÃ½ch',
#   'ĠsfÃ©',
#   'manÅ¯v',
#   'Ġrytmu',
#   'Å¾Ã¡d',
#   'fikovanÃ©',
#   'ĠÃºplnÃ©',
#   'VÃŃce',
#   'ĠvÄĽnovat',
#   'ĠprotÃ¡',
#   'Ġkonzu',
#   'Ġkoleg',
#   'Ġmaleb',
#   'Ġkonstrukce',
#   'ĠslouÄįen',
#   'ĠpraktickÃ½ch',
#   'HlavnÃŃ',
#   'ĠNedo',
#   'ĠnÃ¡poj',
#   'ntÃ¡l',
#   'nejlepÅ¡ÃŃ',
#   'Ġnejmlad',
#   'tina',
#   'ĠMys',
#   'ĠnevÃ¡',
#   'ĠprÃŃjmu',
#   'uret',
#   'ĠpodnikatelskÃ©',
#   'ĠexistujÃŃ',
#   'ĠmÅ¯Å¾ou',
#   'ĠÅ¾ijÃŃcÃŃ',
#   'ĠTereza',
#   'Å¾uje',
#   'ĠjÃŃdlo',
#   'ramek',
#   'ĠvÅ¯nÄĽ',
#   'ĠnÃ¡vÅ¡tÄĽva',
#   'ĠmodernÃŃch',
#   'ĠdÅ¯sledku',
#   'ovanÃ½m',
#   'Å½i',
#   'Ġpodpis',
#   'hlo',
#   'Ġpasu',
#   'ĠzÃ¡ru',
#   'ĠvÃ½sledkÅ¯',
#   'Ġpotravin',
#   'Äįany',
#   'riginÃ¡lnÃŃ',
#   'Ġjednomu',
#   'ÅĪujÃŃcÃŃ',
#   'ĠspadÃ¡',
#   'ĠpouliÄįnÃŃ',
#   'Ġsvita',
#   'Ġletovice',
#   'ĠÄįela',
#   'chne',
#   'nickou',
#   'Ġrozli',
#   'ĠodhalÃŃ',
#   'ĠDÃ¡n',
#   'Ġmamin',
#   'ĠobhÃ¡',
#   'ĠpÅĻejÃŃ',
#   'anis',
#   'ĠzÃ¡vislost',
#   'ĠsmÄĽsi',
#   'cena',
#   'Ġingredience',
#   'Ġsra',
#   'liber',
#   'ĠskrytÃ¡',
#   'ĠdozvÄĽ',
#   'ĠvÃ½Å¡ky',
#   'ĠtÄĽÅ¡ÃŃm',
#   'Ġrezon',
#   'ĠreÅ¾isÃ©ra',
#   'ĠnoÅ¾',
#   'ĠveÄįÃŃ',
#   'ĠuhlÃŃ',
#   'kupe',
#   'vodce',
#   'doba',
#   'Kou',
#   'ĠtÃ©mata',
#   'Ġzisk',
#   'ĠKrista',
#   'ĠkrevnÃŃ',
#   'osice',
#   'ĠvyuÅ¾ili',
#   'Ġpodzi',
#   'livÃ½m',
#   'ĠsÃŃdla',
#   'ĠpodobnÃ©',
#   'ĠmodrÃ¡',
#   'ĠsvÄĽdÄįÃŃ',
#   'itÃ½m',
#   'ĠmanÅ¾elem',
#   'ĠodpoÄįinku',
#   'LAD',
#   'UDr',
#   'varu',
#   'VÅ¡ech',
#   'roh',
#   'dÄĽlala',
#   'ĠpatnÃ¡ct',
#   'ĠztrÃ¡',
#   'Ġplnit',
#   'ĠchemickÃ©',
#   'ĠhospodÃ¡ÅĻstvÃŃ',
#   'Ġpotraviny',
#   'ĠprodÃ¡vajÃŃcÃŃ',
#   'ĠotÄĽ',
#   'tinÄĽ',
#   'lnÄĽ',
#   'ĠchlupatÃ¡',
#   'ĠdomÃ¡cÃŃm',
#   'ĠPomo',
#   'ĠbojÃŃ',
#   'Ġose',
#   'vinÃ¡',
#   'nÄĽnÃŃm',
#   'Ġdopis',
#   'Ġtitu',
#   'peme',
#   'ĠmnÃŃÅ¡ek',
#   'Ġdvo',
#   'povÄĽdÄĽt',
#   'OVÃĿ',
#   'ĠmÄĽÅĻÃŃ',
#   'tud',
#   'Ġpokles',
#   'ĠÄįokolÃ¡dy',
#   'pÄĽ',
#   'skem',
#   'ĠzÃ¡jmÅ¯',
#   'Ġlednice',
#   'Ġosmi',
#   'ĠnÃ¡vrhy',
#   'ĠÅĻeditele',
#   'ĠDomÃ¡cÃŃ',
#   'dejte',
#   'ĠportrÃ©',
#   'Ġpohon',
#   'ĠletiÅ¡tÄĽ',
#   'Ġjednalo',
#   'Ġmapu',
#   'ĠfunkÄįnÃŃ',
#   'ĠpÅĻedstavenÃŃ',
#   'Ġpoch',
#   'ĠzÃ¡da',
#   'Ġtypem',
#   'Å¯Å¾ete',
#   'ĠtÃ©ma',
#   'Ġasistent',
#   'Ġhni',
#   'Ġprezentaci',
#   'ĠAÅ¾',
#   'Ġporucha',
#   'ĠzÃ¡vodÅ¯',
#   'Ġkapky',
#   'ĠuvnitÅĻ',
#   'ĠÅ¡etr',
#   'bÃ¡n',
#   'ĠvidÃŃm',
#   'Ġpotre',
#   'Ġnutnost',
#   'Ġvyme',
#   'ĠhÃ½',
#   'ĠuloÅ¾it',
#   'ĠobÄįanÅ¯',
#   'Ġtrochou',
#   'ĠzvyÅ¡ujÃŃ',
#   'ZÃŃ',
#   'ĠpÅĻestup',
#   'ĠPÃŃs',
#   'kovÃ½mi',
#   'ĠSenÃ¡tu',
#   'prostÅĻed',
#   'Ġbys',
#   'ĠlogickÃ©',
#   'jmenÅ¡ÃŃm',
#   'dÄĽzem',
#   'teru',
#   'ĠnahoÅĻe',
#   'ĠvypadÃ¡',
#   'ĠosobnÄĽ',
#   'Ġnaviga',
#   'ĠmezinÃ¡rodnÃŃho',
#   'ĠStarÃ©',
#   'Ġpleve',
#   'ĠzvÃŃÅĻecÃŃ',
#   'vÅ¡ÃŃ',
#   'ĠnedÃ¡',
#   'ĠovÄĽÅĻit',
#   'ĠsezÃ³',
#   'ĠplatbÄĽ',
#   'ĠpÄĽstovat',
#   'ĠprohlÃŃÅ¾e',
#   'Ġchatu',
#   'Ġoslavy',
#   'ĠtakovÃ©ho',
#   'movÃ¡',
#   'ĠÅ¡krÃ¡',
#   'Ġkontextu',
#   'ĠspeciÃ¡lnÃŃ',
#   'ĠchyÅ¡e',
#   'ĠjednoduchÃ½',
#   'ĠUkÃ¡',
#   'zvlÃ¡',
#   'ĠdÃ¡m',
#   'ĠBeroun',
#   'Ġnovinku',
#   'ĠÅ¡vihov',
#   'ĠprÅ¯vod',
#   'ĠvzpomÃŃ',
#   'ĠpÅĻÃŃpadÅ¯',
#   'ĠbÅĻeznu',
#   'antnÃŃ',
#   'ĠnÅ¯Å¾',
#   'lakt',
#   'ĠhubnutÃŃ',
#   'ĠrodiÄįÅ¯m',
#   'ovci',
#   '?âĢľĊ',
#   'vaceti',
#   'ĠÅ¡enov',
#   'ÄįÃŃme',
#   'Ġodstart',
#   'Kla',
#   'ĠerotickÃ¡',
#   'ĠvÃ½jimky',
#   'Dva',
#   'ĠbateriÃŃ',
#   'ĠstÅ¯l',
#   'ĠStÃ¡',
#   'bliÅ¾Å¡ÃŃ',
#   'ĠhoÅĻe',
#   'Ġcasinu',
#   'ĠpochÃ¡zÃŃ',
#   'ĠkÄį',
#   'Ġnemohla',
#   'ĠmasÃ¡',
#   'zetÃŃ',
#   'kvi',
#   'ĠpÅĻevÃ¡',
#   'ĠdÅ¯chodu',
#   'ĠnemÅ¯Å¾u',
#   'ĠdÃ½ch',
#   'Ġnahoru',
#   'ĠhranÃŃ',
#   'ĠJaroslava',
#   'dÃ¡m',
#   'ĠvÃ½Å¾ivu',
#   'Ġkamene',
#   'Ġstrava',
#   'Ġhluboko',
#   'Ġkonal',
#   'ĠbudoucÃŃch',
#   'ntry',
#   'prosto',
#   'hemale',
#   'ĠkomentÃ¡ÅĻÅ¯',
#   'ĠobrÃ¡zkÅ¯',
#   'vÄĽtÅ¡ÃŃm',
#   'ĠvzÃ¡c',
#   'ĠObjednÃ¡',
#   'ĠpoptÃ¡vka',
#   'Ġoni',
#   'PomocÃŃ',
#   'ĠNÃ¡slednÄĽ',
#   'ĠlÃ¡sce',
#   'ĠUkrajiny',
#   'ĠvystÅĻÃŃ',
#   'ĠstarostÃŃ',
#   'Ġzarago',
#   'ĠgramÅ¯',
#   'ĠkamarÃ¡di',
#   'Ġinvesti',
#   'ĠrobustnÃŃ',
#   'kÃ¡lnÃŃ',
#   'Ġzimu',
#   'kula',
#   'tavou',
#   'Firma',
#   'rÅ¯v',
#   'Ġautomobilu',
#   'ĠzÃŃ',
#   'ĠProblÃ©m',
#   'Ġprona',
#   'Ġkerami',
#   'kovÃ¡ny',
#   'Ġstanou',
#   'SouÄįÃ¡stÃŃ',
#   'uÅ¾',
#   'pomÃŃ',
#   'ĠlaboratoÅĻe',
#   'ĠnepatÅĻÃŃ',
#   'Ġvalen',
#   'ĠurÄįenÃ½ch',
#   'ĠstrÃ¡nce',
#   'ĠverzÃŃ',
#   'Ġvyho',
#   'ĠnÃŃzko',
#   'Ġmotivace',
#   'ĠLucie',
#   'bÃ½vÃ¡',
#   'ĠÄįelÃŃ',
#   'ĠsuÅ¡enÃŃ',
#   'Å¯vodnÃŃ',
#   'ĠdesÃ¡t',
#   'Ġmarketingu',
#   'ĠvyplatÃŃ',
#   'Ġkomor',
#   'ĠiPhonu',
#   'ĠmanuÃ¡lnÃŃ',
#   'ĠuzavÅĻenÃŃ',
#   'jsou',
#   'Ġkoupila',
#   'Ġtechnika',
#   'ĠveterÃ¡',
#   'vacÃŃho',
#   'kovy',
#   'Ġusil',
#   'ĠvedenÃŃm',
#   'Ġzasa',
#   'Ġskladem',
#   'ĠÄĮEZ',
#   'ĠKlepnÄĽte',
#   'ĠlhÅ¯ty',
#   'Ġproslu',
#   'Ġodkaz',
#   'tkov',
#   'ĠstejnÃ©m',
#   'Nakonec',
#   'Ġhotovosti',
#   'ĠvelkÃ©ho',
#   'Ġteple',
#   'jskÃ©ho',
#   'stÄĽ',
#   'ĠznÃ¡mÃ©ho',
#   'Ġnonstop',
#   'ovek',
#   'stÃ©m',
#   'ĠsezÃ³n',
#   'ĠodliÅ¡',
#   'ĠkliknutÃŃ',
#   'ĠvrchnÃŃ',
#   'tÅĻeb',
#   'Ġnoze',
#   'Ġotrav',
#   'Ġplavky',
#   'ĠdlouhÃ½ch',
#   'Ġkonat',
#   'ovaÄįe',
#   'ĠpÅĻeva',
#   'lnÃ¡',
#   'Ġobav',
#   'ĠvÄĽÅĻÃŃm',
#   'Ġtexti',
#   'Hla',
#   'ĠplzeÅĪ',
#   'ĠroÅ¾',
#   'Ġkombinaci',
#   'PÅĻesto',
#   'jel',
#   'ĠpomÅ¯',
#   'Ġvozidlo',
#   'Ġpravdou',
#   'Å¾eno',
#   'ĠprovÃ¡dÃŃ',
#   'chÃ¡zenÃŃ',
#   'ĠvÃ¡leÄį',
#   'nera',
#   'ĠdospÃŃvajÃŃcÃŃ',
#   'ĠÃºÄįinnost',
#   'ĠjedenÃ¡ct',
#   'ĠpÅĻÃŃzni',
#   'ĠtvÃ¡ÅĻe',
#   'Ġzba',
#   'Å¡tinÄĽ',
#   'chala',
#   'ĠbÄĽlo',
#   'ĠdlouhÃ©m',
#   'latÃ½',
#   'ĠÃºc',
#   'Ġjater',
#   'ĠprÃ¡vu',
#   'ĠpraktickÃ¡',
#   'ĠnevÃ½',
#   'ĠvelkÃ¡',
#   'ĠHDP',
#   'Äįu',
#   'ĠsnÃŃdanÄĽ',
#   'ĠrtynÄĽ',
#   'rÃ¡torÅ¯',
#   'stÃ¡',
#   'ĠVele',
#   'stickÃ©',
#   'ĠKlas',
#   'ĠpÅĻibli',
#   'Ġobyt',
#   'ĠopoÄįno',
#   'PrÅ¯',
#   'Ġsrpen',
#   'ĠzatÄĽ',
#   'ĠmladÃ©ho',
#   'ĠpodlÃ©',
#   'Ġdotaz',
#   'ĠnabÃŃdky',
#   'Å¡to',
#   'ĠpodobÄĽ',
#   'ĠpÅĻÃŃpravkÅ¯',
#   'ĠchtÄĽjÃŃ',
#   'lina',
#   'ĠpornohvÄĽzdy',
#   'Ġprojekty',
#   'ĠmÄĽsÃŃci',
#   'drÅ¾i',
#   'ĠmnohÃ©',
#   'ĠnÃŃÅ¾e',
#   'ĠoperÃ¡tor',
#   'ĠproblÃ©mu',
#   'ĠpondÄĽlÃŃ',
#   'Ġvrcho',
#   'lenÃ©',
#   'ĠcestujÃŃcÃŃch',
#   'mili',
#   'erÄįnÃŃ',
#   'Ġdokonale',
#   'Ġumy',
#   'umperk',
#   'Ġstruktura',
#   'jdu',
#   'Ġreakci',
#   'ĠkancelÃ¡ÅĻi',
#   'ovaÄį',
#   'leva',
#   'ĠÄĮeskÃ½ch',
#   'Ġzdi',
#   'ĠumÄĽlci',
#   'nÃŃze',
#   'ĠkasinovÃ©',
#   'Ġokolnosti',
#   'Ġvolbu',
#   'ĠvÃŃtÃ¡',
#   'Ġzapomenout',
#   'ĠjÃŃc',
#   'ondr',
#   'ĠLÃ¡znÄĽ',
#   'ĠlesbickÃ½',
#   'Ġodbornou',
#   'Ġprud',
#   'Ġinsta',
#   'dÃ¡nice',
#   'NÃŃ',
#   'ĠzmÃŃrnit',
#   'ĠpeÄįky',
#   'ĠvelkÃ©m',
#   'ĠvyjÃ¡dÅĻenÃŃ',
#   'ĠregistrÅ¯',
#   'ĠkontaktÅ¯',
#   'Ġjara',
#   'kona',
#   'Ġtachov',
#   'ĠmÄĽsÃŃcem',
#   'ĠtÃ½dennÃŃ',
#   'ĠzruÅ¡enÃŃ',
#   'ĠÃºle',
#   'ĠSled',
#   'Ġkryt',
#   'ĠBritÃ¡nie',
#   'kovanÃ¡',
#   'Ġdetaily',
#   'ĠHasi',
#   'ĠvojÃ¡kÅ¯',
#   'ĠdÅ¯leÅ¾itÃ½m',
#   'liÃŃ',
#   'Vyu',
#   'vanÃ½ch',
#   'ĠPoli',
#   'ĠÅĻeÅ¡ÃŃ',
#   'Ġredakce',
#   'ĠvÃŃm',
#   'ĠuÅ¾iteÄįnÃ½ch',
#   'pka',
#   'ĠlitvÃŃnov',
#   'ĠvzdÃ¡lenosti',
#   'ĠVyplÃ½vÃ¡',
#   'ĠsvatebnÃŃ',
#   'Ġstanici',
#   'Ġkonstat',
#   'ĠMoc',
#   'Ġmasi',
#   'Ġrovno',
#   'Ġuklid',
#   'Ġmoje',
#   'ĠbohatÃ¡',
#   'Ġportu',
#   'Ġchrupa',
#   'padnÃŃ',
#   'ĠlÃ©kÃ¡rnÄĽ',
#   'telnÄĽ',
#   'Ġdota',
#   'ĠumÃ½',
#   'ĠudrÅ¾itel',
#   'linu',
#   'ĠDÄĽt',
#   'ĠzahÃ¡jit',
#   'ĠtÅĻem',
#   'ĠskupinÄĽ',
#   'Ġzame',
#   'Ġboje',
#   'ÃįN',
#   'Ġpravidlo',
#   'Ġvyhovovat',
#   'ĠvolÃ¡nÃŃ',
#   'Ġfeti',
#   'ĠÅ¡irÅ¡ÃŃ',
#   'ĠjarnÃŃ',
#   'Ġmikulov',
#   'Ġantibak',
#   'ĠpostavenÃŃ',
#   'ĠposkytovatelÅ¯',
#   'bujÃŃ',
#   'ĠtlouÅ¡Å¥',
#   'ĠcÃŃtil',
#   'Ġnaslou',
#   'ĠÅĻÃ¡dek',
#   'ĠvdanÃ©',
#   'ĠrozÅ¡ÃŃÅĻit',
#   'rozÃŃ',
#   'NapÅĻÃŃklad',
#   'ĠÃºloÅ¾iÅ¡tÄĽ',
#   'nony',
#   'Ġvytvo',
#   'Ġarcheolog',
#   'ĠnedÃ¡vnÃ©',
#   'ĠkrÃ©m',
#   'ĠzÃ¡stupcÅ¯',
#   'ĠpoÅ¡t',
#   'ĠFortu',
#   'ĠpÅĻednÃ¡Å¡ky',
#   'Ġmedaili',
#   'ĠMiroslav',
#   'stÅ¯m',
#   'ĠprÃŃ',
#   'kru',
#   'ĠÅ¾eleznice',
#   'pil',
#   'mati',
#   'bÃ¡t',
#   'tnov',
#   'ĠSnÃŃ',
#   'Ġspokojen',
#   'ĠzÃŃskÃ¡te',
#   'covÃ©',
#   'ĠvydÄĽlÃ¡',
#   'ĠstavÄĽ',
#   'NebankovnÃŃ',
#   'ĠÅ¾eb',
#   'ĠpouÅ¾ijte',
#   'ĠbezproblÃ©m',
#   'tika',
#   'Ġmajitel',
#   'ĠObÄįas',
#   'Ġnata',
#   'odol',
#   'ĠporozumÄĽt',
#   'ĠrovnÃ©',
#   'Ġpasi',
#   'ĠÅĻeÄįice',
#   'ĠÅ¾enatÃ½',
#   'Ġmozek',
#   'Ġspeciali',
#   'Ġnejroz',
#   'ĠZku',
#   'ĠnÃ½rsko',
#   'ĠdokonÄįit',
#   'mÄĽrnÃ¡',
#   'ĠrovinÄĽ',
#   'ĠnemusÃŃ',
#   'ĠhistorickÃ©',
#   'ĠÄįle',
#   'Ġkalo',
#   'letu',
#   'Ġfyzicky',
#   'ĠpÃ©ÄįÃŃ',
#   'Ġosa',
#   'ĠpÃŃsku',
#   'ĠÅ¡irokou',
#   'Å¾itek',
#   'dalo',
#   'ĠuklÃ¡dÃ¡nÃŃ',
#   'lze',
#   'ÅĻednÃŃ',
#   'videa',
#   'Ġtechnologii',
#   'Ġkina',
#   'ĠmÄĽÅĻit',
#   'ĠzÃ¡pad',
#   'Ġopilec',
#   'Ġ:-)Ċ',
#   'ÅĻnÃŃ',
#   'Ġmedu',
#   'ĠzaplatÃŃ',
#   'ĠsvÄĽtovÃ©',
#   'ĠanÃ¡lnÃŃho',
#   'Ġposti',
#   'akce',
#   'Ġtole',
#   'ĠÄįele',
#   'MyslÃŃm',
#   'ĠnemÃ¡m',
#   'poruje',
#   'ĠuklÃ¡dÃ¡',
#   'ĠnejnovÄĽjÅ¡ÃŃch',
#   'ĠOstrav',
#   'Ġope',
#   'ĠtroÅ¡ku',
#   'ĠstÄĽnÄĽ',
#   'Ġzob',
#   'Ġobnovy',
#   'ĠkrÃ¡sa',
#   'lici',
#   'ĠÅ¡am',
#   'ĠpÅĻedse',
#   'ĠchÅĻibskÃ¡',
#   'Ġligy',
#   'zemnÃŃ',
#   'Petr',
#   'Ġzouf',
#   'ĠvÄĽÅĻi',
#   'Ġkapacit',
#   'hlaste',
#   'Ãļvod',
#   'Ġnapa',
#   'ĠvyplÃ½',
#   'ĠmÄĽÅĻÃŃtku',
#   'tolog',
#   'ĠzÃ¡vratÄĽ',
#   'bÃŃzÃŃme',
#   'ovatelnÃ©',
#   'ĠmladÅ¡ÃŃch',
#   'Ġkach',
#   'ĠbazÃ©n',
#   'Ġsvobody',
#   'sivnÃŃ',
#   'ĠÃºdrÅ¾bu',
#   'Ġeti',
#   'ĠpartnerstvÃŃ',
#   'ĠkÅĻÃŃÅ¾',
#   'ĠdostateÄįnÄĽ',
#   'ĠVlÃ¡da',
#   'Ġnedodr',
#   'ĠklÃŃÄįe',
#   'ĠuÄįÃŃ',
#   'Ġmohelnice',
#   'Ġsehnat',
#   'Ġbudoucnosti',
#   'vÅ¯r',
#   'ĠnÃ¡vÅ¡tÄĽvnÃŃkÅ¯m',
#   'ĠmastnÃ½ch',
#   'plÅĪ',
#   'ĠnÄĽÄįem',
#   'Ġpotiskem',
#   'ĠnÄĽmeckÃ½',
#   'ĠodbÄĽ',
#   'ĠzatÃ¡',
#   'ĠjasnÄĽ',
#   'ĠmÃŃstnost',
#   'ĠÅ¾dÃ¡nice',
#   'ĠnÃ¡mÄĽ',
#   'ĠuvolnÄĽ',
#   'ĠbarvÄĽ',
#   'tÃ©ho',
#   'ĠkrÃ¡tkodobÃ¡',
#   'ĠpoÄįty',
#   'Ġkosmetiky',
#   'ĠvÅ¡eobec',
#   'Ġzpravodaj',
#   'ĠnepÅ¯j',
#   'dajÃŃcÃŃ',
#   'ĠVladi',
#   'Ġtvo',
#   'mnÄĽ',
#   'ĠdomÃ¡cnost',
#   'rÃ¡k',
#   'stil',
#   'Ġvysta',
#   'Ġmalin',
#   'vÃŃte',
#   'Ġteku',
#   'Ġnedo',
#   'itelnÃ½ch',
#   'ĠNakonec',
#   'Ġturna',
#   'ĠPotÅĻeb',
#   'Ġhistoricky',
#   'ĠdrÅ¾ÃŃ',
#   'kujte',
#   'ĠskvÄĽle',
#   'Ġsoupe',
#   'ĠdÄĽlal',
#   'Ġinovace',
#   'ĠzÃ¡pach',
#   'Ġseveru',
#   'JakÃ½',
#   'ĠÅĻÃŃÄįany',
#   'Ġturnaje',
#   'ĠvlastnostÃŃ',
#   'Ġnutnosti',
#   'stoupit',
#   'ĠsplÃ¡',
#   'ĠdolnÃŃ',
#   'JÃį',
#   'ĠnÃ¡la',
#   'Ġvyne',
#   'ĠvyÅ¾adovat',
#   'ymburk',
#   'ĠzvÃŃtÄĽ',
#   'ĠpatologiÃŃ',
#   'ĠmedicÃŃ',
#   'Ġvelvary',
#   'Ġtechnologiemi',
#   'ĠÄįtvrti',
#   'ĠostatnÃŃm',
#   'ĠFinanÄįnÃŃ',
#   'zÃ¡jem',
#   'ĠlÃ©ÄįivÃ©',
#   'ĠpouÅ¾ÃŃvanÃ©',
#   'Ġpokr',
#   'lovou',
#   'tÃ½',
#   'Ġreceptu',
#   'zdrav',
#   'ĠneplatÃŃ',
#   'ĠveÅĻejnÃ½',
#   'lÃŃku',
#   'mnÄĽli',
#   'ĠproblÃ©mÅ¯m',
#   'ĠslabÃ©',
#   'paÅĪ',
#   'ĠpoznÃ¡',
#   'Ġstolice',
#   'rcha',
#   'ĠvÃ¡Å¡eÅĪ',
#   'ĠtÄĽÅ¾kou',
#   'RÃ¡di',
#   'hrÃ¡l',
#   'ĠexternÃŃ',
#   'ĠpodrÃ¡Å¾',
#   'bran',
#   'ĠtkÃ¡nÄĽ',
#   'Ġkomise',
#   'ĠprokÃ¡zat',
#   'ĠbunÄĽk',
#   'ĠzaÄįaly',
#   'Ġnahradit',
#   'Rok',
#   'ĠneÄįekanÄĽ',
#   'ĠsvÄĽdky',
#   'ĠNynÃŃ',
#   'ĠÅ¾Ã¡dost',
#   'PÅĻeÄįtÄĽte',
#   'Ġjakoukoli',
#   'Å¡enÃ©',
#   'ĠrozmÄĽr',
#   'mentÃ¡lnÃŃ',
#   'ĠkrÃ¡lovÃ©',
#   'Ġhodo',
#   'NÃ¡zev',
#   'Ġsedmi',
#   'Ġpoci',
#   'ĠvytvoÅĻit',
#   'Ġkrav',
#   'Ã¡ÅĻÅ¯',
#   'ĠzboÅ¾ÃŃm',
#   'zovou',
#   'Ġsouprava',
#   'ĠpozdÄĽjÅ¡ÃŃ',
#   'ĠmanÅ¾elky',
#   'bÄĽÅ¾',
#   'ĠÄĮÃ¡st',
#   'ĠdopravnÃŃ',
#   'ĠinteligentnÃŃ',
#   'Ġhoupa',
#   'ĠovlÃ¡',
#   'ĠRÃ¡',
#   'Ġdetoxi',
#   'NejlepÅ¡ÃŃ',
#   'Ġvlivu',
#   'ĠÅ¡ÃŃÅĻku',
#   'pustit',
#   'Ġchud',
#   'ĠzjiÅ¡tÄĽ',
#   'ÅĻitom',
#   'Ġabnor',
#   'ĠdocÃŃ',
#   'nojmen',
#   'Ġnero',
#   'Ġrozpoznat',
#   'vaci',
#   'ĠkolÃ¡',
#   'ĠnÃ¡kladnÃŃ',
#   'poÄįtu',
#   'abÃ¡',
#   'Ġorgasmus',
#   'ĠdozvÄĽdÄĽt',
#   'ekÃ½n',
#   'havÄĽjÅ¡ÃŃ',
#   'krÃ¡',
#   'ĠÄįeskou',
#   'ĠsmÄĽs',
#   'ĠZadejte',
#   'ĠvÄĽkovÃ©',
#   'ĠdaÅĪovÃ©ho',
#   'Ġnemlu',
#   'Ġjistotu',
#   'rÃ¡Å¾ky',
#   'vÃ¡nÃŃm',
#   'ĠpeÄįi',
#   'ĠzasÃŃlÃ¡nÃŃ',
#   'ĠpouÅ¾ÃŃvÃ¡m',
#   'Ġsval',
#   'Ġautobusu',
#   'ĠdodÃ¡vajÃŃ',
#   'ĠzdÃ¡n',
#   'stitu',
#   'ÅĻÃŃÅ¾i',
#   'ssic',
#   'vii',
#   'Ġproduktem',
#   'ĠvÃ½le',
#   'ĠrÅ¯znÄĽ',
#   'ĠorlicÃŃ',
#   'ranit',
#   'Jednodu',
#   'Ġvyslov',
#   'veklov',
#   'rÃ¡la',
#   'aktivnÃŃ',
#   'minace',
#   'ĠvÄĽtÅĻnÃŃ',
#   'lÃŃk',
#   'ĠkÃ½m',
#   'leji',
#   'Ġvyvinut',
#   'Ġgastrointestin',
#   'ĠÅ¡patnÃ©',
#   'Ġbrada',
#   'ĠsezÃ³nu',
#   'ĠspolehlivÃ©',
#   'ĠsvÄĽdÄĽnÃŃ',
#   'ĠmodrÃ½',
#   'ĠrozmezÃŃ',
#   'Ġvyhodno',
#   'ĠdÄĽjin',
#   'Ġspravedl',
#   'ĠjelikoÅ¾',
#   'zovat',
#   'lovy',
#   'hlÃ©',
#   'ĠnÄĽme',
#   'ZajÃŃma',
#   'ĠsprÃ¡vnÃ½m',
#   'Ġpodpa',
#   'perskÃ©',
#   'ĠzdvojnÃ¡sob',
#   'Ġtlaku',
#   'nÃ¡cti',
#   'ĠpÅĻedpla',
#   'Å¾nicÃŃ',
#   'ĠdenÃŃku',
#   'ĠpoÅ¾ada',
#   'tÅĻeba',
#   'Ġuvi',
#   'ĠhvÄĽzdy',
#   'Ġroztr',
#   'ĠpÅĻihlÃ¡Å¡enÃŃ',
#   'Ġkolegy',
#   'ÄĮeskÃ½',
#   'Ġsymptomy',
#   'tiÅ¡tÄĽ',
#   'ĠvÃ½voji',
#   'ĠzaznamenÃ¡',
#   'Ġcidlinou',
#   'hereum',
#   'Å¾is',
#   'StÃ¡',
#   'Ġokraj',
#   'ĠpÅĻÃŃjemnou',
#   'Ġrakov',
#   'ĠzÅ¯stÃ¡vajÃŃ',
#   'Ġpochyb',
#   'ĠÄįeskosloven',
#   '.CZ',
#   'ĠÃºlo',
#   'Ġzima',
#   'ĠpÅĻesmÄĽ',
#   'ĠMusÃŃm',
#   'ĠjÃ¡t',
#   'utnat',
#   'ĠpÅĻechod',
#   'ĠÃºdrÅ¾',
#   'Å¡ÃŃnem',
#   'ĠÅ¡ortky',
#   'ĠzamÄĽÅĻena',
#   'louse',
#   'ĠodmÄĽnu',
#   'ĠinzerÃ¡ty',
#   'ĠuÅ¡ÃŃ',
#   'Ġporodu',
#   'ĠvÃŃkendu',
#   'ĠÄįesko',
#   'ĠvyspÄĽ',
#   'Ġvcelku',
#   'ĠÅĻidiÄįi',
#   'zÃŃm',
#   'dÄĽlÃ¡nÃŃ',
#   'ĠakorÃ¡t',
#   'ĠdÅ¯klad',
#   'ĠvÃ½bor',
#   'Ġposlan',
#   'Ġvelvy',
#   'Ġsezemice',
#   'Ġrobu',
#   'hotovo',
#   'ĠoseÄįnÃ¡',
#   'ĠÅ¾ehli',
#   'ĠÃºvodu',
#   'ĠpÅĻipravenÃ©',
#   'Ġsleduje',
#   'ĠUvi',
#   'ardnÃŃ',
#   'sÃ¡no',
#   'ĠduÅ¡evnÃŃ',
#   'ĠcviÄįenÃŃ',
#   'Ġdesku',
#   'fou',
#   'ĠinternetovÃ¡',
#   'ĠrozhodÄįÃŃ',
#   'Tyto',
#   'ĠuzavÅĻena',
#   'ĠpÃ¡rty',
#   'byla',
#   'jaku',
#   'ĠdÄĽdi',
#   'Ã³znÃŃ',
#   'Ġsnahy',
#   'anu',
#   'ĠTohle',
#   'ĠhanÃ©',
#   'kument',
#   'ĠsdÄĽli',
#   'ĠnezÃ¡',
#   'jetÃŃ',
#   'Ġsankce',
#   'Recenze',
#   'ĠBabi',
#   'datel',
#   'Å¡nÃ½ch',
#   'ĠÃºpravÄĽ',
#   'ĠzaloÅ¾enÃŃ',
#   'ĠÄįerst',
#   'tÃ¡ch',
#   'ĠZvÃ½',
#   'ckÃ©',
#   'lustraÄįnÃŃ',
#   'Ġprincipu',
#   ':|Ċ',
#   'Ġkno',
#   'nali',
#   'hledÃ¡nÃŃ',
#   'okup',
#   'Ġsucho',
#   ...},
#  17017)

# %%
new_tokens = list(diff_vocab)
new_tokens
# Out:
# ['Ġnasy',
#  'Ġvstupenky',
#  'ÅĻadu',
#  'Ġvce',
#  'teÄįnÃ½m',
#  'Ġdezer',
#  'ĠaÄį',
#  'ĠpÅĻedstaven',
#  'spod',
#  'ĠudÄĽlala',
#  'venÃŃ',
#  'ĠpÄĽknÄĽ',
#  'ĠdÃŃlny',
#  'hovÃ©',
#  'ĠDisku',
#  'ĠtÄĽÅ¾kÃ¡',
#  'ĠstÅĻihu',
#  'Ġpum',
#  'ĠsouÄįasnÄĽ',
#  'ĠdobrÃ½m',
#  '|Hmotnost',
#  'Ġkoru',
#  'Ġosoba',
#  'Ġspustit',
#  'ĠÄįernÃ½ch',
#  'ĠsfÃ©',
#  'manÅ¯v',
#  'Ġrytmu',
#  'Å¾Ã¡d',
#  'fikovanÃ©',
#  'ĠÃºplnÃ©',
#  'VÃŃce',
#  'ĠvÄĽnovat',
#  'ĠprotÃ¡',
#  'Ġkonzu',
#  'Ġkoleg',
#  'Ġmaleb',
#  'Ġkonstrukce',
#  'ĠslouÄįen',
#  'ĠpraktickÃ½ch',
#  'HlavnÃŃ',
#  'ĠNedo',
#  'ĠnÃ¡poj',
#  'ntÃ¡l',
#  'nejlepÅ¡ÃŃ',
#  'Ġnejmlad',
#  'tina',
#  'ĠMys',
#  'ĠnevÃ¡',
#  'ĠprÃŃjmu',
#  'uret',
#  'ĠpodnikatelskÃ©',
#  'ĠexistujÃŃ',
#  'ĠmÅ¯Å¾ou',
#  'ĠÅ¾ijÃŃcÃŃ',
#  'ĠTereza',
#  'Å¾uje',
#  'ĠjÃŃdlo',
#  'ramek',
#  'ĠvÅ¯nÄĽ',
#  'ĠnÃ¡vÅ¡tÄĽva',
#  'ĠmodernÃŃch',
#  'ĠdÅ¯sledku',
#  'ovanÃ½m',
#  'Å½i',
#  'Ġpodpis',
#  'hlo',
#  'Ġpasu',
#  'ĠzÃ¡ru',
#  'ĠvÃ½sledkÅ¯',
#  'Ġpotravin',
#  'Äįany',
#  'riginÃ¡lnÃŃ',
#  'Ġjednomu',
#  'ÅĪujÃŃcÃŃ',
#  'ĠspadÃ¡',
#  'ĠpouliÄįnÃŃ',
#  'Ġsvita',
#  'Ġletovice',
#  'ĠÄįela',
#  'chne',
#  'nickou',
#  'Ġrozli',
#  'ĠodhalÃŃ',
#  'ĠDÃ¡n',
#  'Ġmamin',
#  'ĠobhÃ¡',
#  'ĠpÅĻejÃŃ',
#  'anis',
#  'ĠzÃ¡vislost',
#  'ĠsmÄĽsi',
#  'cena',
#  'Ġingredience',
#  'Ġsra',
#  'liber',
#  'ĠskrytÃ¡',
#  'ĠdozvÄĽ',
#  'ĠvÃ½Å¡ky',
#  'ĠtÄĽÅ¡ÃŃm',
#  'Ġrezon',
#  'ĠreÅ¾isÃ©ra',
#  'ĠnoÅ¾',
#  'ĠveÄįÃŃ',
#  'ĠuhlÃŃ',
#  'kupe',
#  'vodce',
#  'doba',
#  'Kou',
#  'ĠtÃ©mata',
#  'Ġzisk',
#  'ĠKrista',
#  'ĠkrevnÃŃ',
#  'osice',
#  'ĠvyuÅ¾ili',
#  'Ġpodzi',
#  'livÃ½m',
#  'ĠsÃŃdla',
#  'ĠpodobnÃ©',
#  'ĠmodrÃ¡',
#  'ĠsvÄĽdÄįÃŃ',
#  'itÃ½m',
#  'ĠmanÅ¾elem',
#  'ĠodpoÄįinku',
#  'LAD',
#  'UDr',
#  'varu',
#  'VÅ¡ech',
#  'roh',
#  'dÄĽlala',
#  'ĠpatnÃ¡ct',
#  'ĠztrÃ¡',
#  'Ġplnit',
#  'ĠchemickÃ©',
#  'ĠhospodÃ¡ÅĻstvÃŃ',
#  'Ġpotraviny',
#  'ĠprodÃ¡vajÃŃcÃŃ',
#  'ĠotÄĽ',
#  'tinÄĽ',
#  'lnÄĽ',
#  'ĠchlupatÃ¡',
#  'ĠdomÃ¡cÃŃm',
#  'ĠPomo',
#  'ĠbojÃŃ',
#  'Ġose',
#  'vinÃ¡',
#  'nÄĽnÃŃm',
#  'Ġdopis',
#  'Ġtitu',
#  'peme',
#  'ĠmnÃŃÅ¡ek',
#  'Ġdvo',
#  'povÄĽdÄĽt',
#  'OVÃĿ',
#  'ĠmÄĽÅĻÃŃ',
#  'tud',
#  'Ġpokles',
#  'ĠÄįokolÃ¡dy',
#  'pÄĽ',
#  'skem',
#  'ĠzÃ¡jmÅ¯',
#  'Ġlednice',
#  'Ġosmi',
#  'ĠnÃ¡vrhy',
#  'ĠÅĻeditele',
#  'ĠDomÃ¡cÃŃ',
#  'dejte',
#  'ĠportrÃ©',
#  'Ġpohon',
#  'ĠletiÅ¡tÄĽ',
#  'Ġjednalo',
#  'Ġmapu',
#  'ĠfunkÄįnÃŃ',
#  'ĠpÅĻedstavenÃŃ',
#  'Ġpoch',
#  'ĠzÃ¡da',
#  'Ġtypem',
#  'Å¯Å¾ete',
#  'ĠtÃ©ma',
#  'Ġasistent',
#  'Ġhni',
#  'Ġprezentaci',
#  'ĠAÅ¾',
#  'Ġporucha',
#  'ĠzÃ¡vodÅ¯',
#  'Ġkapky',
#  'ĠuvnitÅĻ',
#  'ĠÅ¡etr',
#  'bÃ¡n',
#  'ĠvidÃŃm',
#  'Ġpotre',
#  'Ġnutnost',
#  'Ġvyme',
#  'ĠhÃ½',
#  'ĠuloÅ¾it',
#  'ĠobÄįanÅ¯',
#  'Ġtrochou',
#  'ĠzvyÅ¡ujÃŃ',
#  'ZÃŃ',
#  'ĠpÅĻestup',
#  'ĠPÃŃs',
#  'kovÃ½mi',
#  'ĠSenÃ¡tu',
#  'prostÅĻed',
#  'Ġbys',
#  'ĠlogickÃ©',
#  'jmenÅ¡ÃŃm',
#  'dÄĽzem',
#  'teru',
#  'ĠnahoÅĻe',
#  'ĠvypadÃ¡',
#  'ĠosobnÄĽ',
#  'Ġnaviga',
#  'ĠmezinÃ¡rodnÃŃho',
#  'ĠStarÃ©',
#  'Ġpleve',
#  'ĠzvÃŃÅĻecÃŃ',
#  'vÅ¡ÃŃ',
#  'ĠnedÃ¡',
#  'ĠovÄĽÅĻit',
#  'ĠsezÃ³',
#  'ĠplatbÄĽ',
#  'ĠpÄĽstovat',
#  'ĠprohlÃŃÅ¾e',
#  'Ġchatu',
#  'Ġoslavy',
#  'ĠtakovÃ©ho',
#  'movÃ¡',
#  'ĠÅ¡krÃ¡',
#  'Ġkontextu',
#  'ĠspeciÃ¡lnÃŃ',
#  'ĠchyÅ¡e',
#  'ĠjednoduchÃ½',
#  'ĠUkÃ¡',
#  'zvlÃ¡',
#  'ĠdÃ¡m',
#  'ĠBeroun',
#  'Ġnovinku',
#  'ĠÅ¡vihov',
#  'ĠprÅ¯vod',
#  'ĠvzpomÃŃ',
#  'ĠpÅĻÃŃpadÅ¯',
#  'ĠbÅĻeznu',
#  'antnÃŃ',
#  'ĠnÅ¯Å¾',
#  'lakt',
#  'ĠhubnutÃŃ',
#  'ĠrodiÄįÅ¯m',
#  'ovci',
#  '?âĢľĊ',
#  'vaceti',
#  'ĠÅ¡enov',
#  'ÄįÃŃme',
#  'Ġodstart',
#  'Kla',
#  'ĠerotickÃ¡',
#  'ĠvÃ½jimky',
#  'Dva',
#  'ĠbateriÃŃ',
#  'ĠstÅ¯l',
#  'ĠStÃ¡',
#  'bliÅ¾Å¡ÃŃ',
#  'ĠhoÅĻe',
#  'Ġcasinu',
#  'ĠpochÃ¡zÃŃ',
#  'ĠkÄį',
#  'Ġnemohla',
#  'ĠmasÃ¡',
#  'zetÃŃ',
#  'kvi',
#  'ĠpÅĻevÃ¡',
#  'ĠdÅ¯chodu',
#  'ĠnemÅ¯Å¾u',
#  'ĠdÃ½ch',
#  'Ġnahoru',
#  'ĠhranÃŃ',
#  'ĠJaroslava',
#  'dÃ¡m',
#  'ĠvÃ½Å¾ivu',
#  'Ġkamene',
#  'Ġstrava',
#  'Ġhluboko',
#  'Ġkonal',
#  'ĠbudoucÃŃch',
#  'ntry',
#  'prosto',
#  'hemale',
#  'ĠkomentÃ¡ÅĻÅ¯',
#  'ĠobrÃ¡zkÅ¯',
#  'vÄĽtÅ¡ÃŃm',
#  'ĠvzÃ¡c',
#  'ĠObjednÃ¡',
#  'ĠpoptÃ¡vka',
#  'Ġoni',
#  'PomocÃŃ',
#  'ĠNÃ¡slednÄĽ',
#  'ĠlÃ¡sce',
#  'ĠUkrajiny',
#  'ĠvystÅĻÃŃ',
#  'ĠstarostÃŃ',
#  'Ġzarago',
#  'ĠgramÅ¯',
#  'ĠkamarÃ¡di',
#  'Ġinvesti',
#  'ĠrobustnÃŃ',
#  'kÃ¡lnÃŃ',
#  'Ġzimu',
#  'kula',
#  'tavou',
#  'Firma',
#  'rÅ¯v',
#  'Ġautomobilu',
#  'ĠzÃŃ',
#  'ĠProblÃ©m',
#  'Ġprona',
#  'Ġkerami',
#  'kovÃ¡ny',
#  'Ġstanou',
#  'SouÄįÃ¡stÃŃ',
#  'uÅ¾',
#  'pomÃŃ',
#  'ĠlaboratoÅĻe',
#  'ĠnepatÅĻÃŃ',
#  'Ġvalen',
#  'ĠurÄįenÃ½ch',
#  'ĠstrÃ¡nce',
#  'ĠverzÃŃ',
#  'Ġvyho',
#  'ĠnÃŃzko',
#  'Ġmotivace',
#  'ĠLucie',
#  'bÃ½vÃ¡',
#  'ĠÄįelÃŃ',
#  'ĠsuÅ¡enÃŃ',
#  'Å¯vodnÃŃ',
#  'ĠdesÃ¡t',
#  'Ġmarketingu',
#  'ĠvyplatÃŃ',
#  'Ġkomor',
#  'ĠiPhonu',
#  'ĠmanuÃ¡lnÃŃ',
#  'ĠuzavÅĻenÃŃ',
#  'jsou',
#  'Ġkoupila',
#  'Ġtechnika',
#  'ĠveterÃ¡',
#  'vacÃŃho',
#  'kovy',
#  'Ġusil',
#  'ĠvedenÃŃm',
#  'Ġzasa',
#  'Ġskladem',
#  'ĠÄĮEZ',
#  'ĠKlepnÄĽte',
#  'ĠlhÅ¯ty',
#  'Ġproslu',
#  'Ġodkaz',
#  'tkov',
#  'ĠstejnÃ©m',
#  'Nakonec',
#  'Ġhotovosti',
#  'ĠvelkÃ©ho',
#  'Ġteple',
#  'jskÃ©ho',
#  'stÄĽ',
#  'ĠznÃ¡mÃ©ho',
#  'Ġnonstop',
#  'ovek',
#  'stÃ©m',
#  'ĠsezÃ³n',
#  'ĠodliÅ¡',
#  'ĠkliknutÃŃ',
#  'ĠvrchnÃŃ',
#  'tÅĻeb',
#  'Ġnoze',
#  'Ġotrav',
#  'Ġplavky',
#  'ĠdlouhÃ½ch',
#  'Ġkonat',
#  'ovaÄįe',
#  'ĠpÅĻeva',
#  'lnÃ¡',
#  'Ġobav',
#  'ĠvÄĽÅĻÃŃm',
#  'Ġtexti',
#  'Hla',
#  'ĠplzeÅĪ',
#  'ĠroÅ¾',
#  'Ġkombinaci',
#  'PÅĻesto',
#  'jel',
#  'ĠpomÅ¯',
#  'Ġvozidlo',
#  'Ġpravdou',
#  'Å¾eno',
#  'ĠprovÃ¡dÃŃ',
#  'chÃ¡zenÃŃ',
#  'ĠvÃ¡leÄį',
#  'nera',
#  'ĠdospÃŃvajÃŃcÃŃ',
#  'ĠÃºÄįinnost',
#  'ĠjedenÃ¡ct',
#  'ĠpÅĻÃŃzni',
#  'ĠtvÃ¡ÅĻe',
#  'Ġzba',
#  'Å¡tinÄĽ',
#  'chala',
#  'ĠbÄĽlo',
#  'ĠdlouhÃ©m',
#  'latÃ½',
#  'ĠÃºc',
#  'Ġjater',
#  'ĠprÃ¡vu',
#  'ĠpraktickÃ¡',
#  'ĠnevÃ½',
#  'ĠvelkÃ¡',
#  'ĠHDP',
#  'Äįu',
#  'ĠsnÃŃdanÄĽ',
#  'ĠrtynÄĽ',
#  'rÃ¡torÅ¯',
#  'stÃ¡',
#  'ĠVele',
#  'stickÃ©',
#  'ĠKlas',
#  'ĠpÅĻibli',
#  'Ġobyt',
#  'ĠopoÄįno',
#  'PrÅ¯',
#  'Ġsrpen',
#  'ĠzatÄĽ',
#  'ĠmladÃ©ho',
#  'ĠpodlÃ©',
#  'Ġdotaz',
#  'ĠnabÃŃdky',
#  'Å¡to',
#  'ĠpodobÄĽ',
#  'ĠpÅĻÃŃpravkÅ¯',
#  'ĠchtÄĽjÃŃ',
#  'lina',
#  'ĠpornohvÄĽzdy',
#  'Ġprojekty',
#  'ĠmÄĽsÃŃci',
#  'drÅ¾i',
#  'ĠmnohÃ©',
#  'ĠnÃŃÅ¾e',
#  'ĠoperÃ¡tor',
#  'ĠproblÃ©mu',
#  'ĠpondÄĽlÃŃ',
#  'Ġvrcho',
#  'lenÃ©',
#  'ĠcestujÃŃcÃŃch',
#  'mili',
#  'erÄįnÃŃ',
#  'Ġdokonale',
#  'Ġumy',
#  'umperk',
#  'Ġstruktura',
#  'jdu',
#  'Ġreakci',
#  'ĠkancelÃ¡ÅĻi',
#  'ovaÄį',
#  'leva',
#  'ĠÄĮeskÃ½ch',
#  'Ġzdi',
#  'ĠumÄĽlci',
#  'nÃŃze',
#  'ĠkasinovÃ©',
#  'Ġokolnosti',
#  'Ġvolbu',
#  'ĠvÃŃtÃ¡',
#  'Ġzapomenout',
#  'ĠjÃŃc',
#  'ondr',
#  'ĠLÃ¡znÄĽ',
#  'ĠlesbickÃ½',
#  'Ġodbornou',
#  'Ġprud',
#  'Ġinsta',
#  'dÃ¡nice',
#  'NÃŃ',
#  'ĠzmÃŃrnit',
#  'ĠpeÄįky',
#  'ĠvelkÃ©m',
#  'ĠvyjÃ¡dÅĻenÃŃ',
#  'ĠregistrÅ¯',
#  'ĠkontaktÅ¯',
#  'Ġjara',
#  'kona',
#  'Ġtachov',
#  'ĠmÄĽsÃŃcem',
#  'ĠtÃ½dennÃŃ',
#  'ĠzruÅ¡enÃŃ',
#  'ĠÃºle',
#  'ĠSled',
#  'Ġkryt',
#  'ĠBritÃ¡nie',
#  'kovanÃ¡',
#  'Ġdetaily',
#  'ĠHasi',
#  'ĠvojÃ¡kÅ¯',
#  'ĠdÅ¯leÅ¾itÃ½m',
#  'liÃŃ',
#  'Vyu',
#  'vanÃ½ch',
#  'ĠPoli',
#  'ĠÅĻeÅ¡ÃŃ',
#  'Ġredakce',
#  'ĠvÃŃm',
#  'ĠuÅ¾iteÄįnÃ½ch',
#  'pka',
#  'ĠlitvÃŃnov',
#  'ĠvzdÃ¡lenosti',
#  'ĠVyplÃ½vÃ¡',
#  'ĠsvatebnÃŃ',
#  'Ġstanici',
#  'Ġkonstat',
#  'ĠMoc',
#  'Ġmasi',
#  'Ġrovno',
#  'Ġuklid',
#  'Ġmoje',
#  'ĠbohatÃ¡',
#  'Ġportu',
#  'Ġchrupa',
#  'padnÃŃ',
#  'ĠlÃ©kÃ¡rnÄĽ',
#  'telnÄĽ',
#  'Ġdota',
#  'ĠumÃ½',
#  'ĠudrÅ¾itel',
#  'linu',
#  'ĠDÄĽt',
#  'ĠzahÃ¡jit',
#  'ĠtÅĻem',
#  'ĠskupinÄĽ',
#  'Ġzame',
#  'Ġboje',
#  'ÃįN',
#  'Ġpravidlo',
#  'Ġvyhovovat',
#  'ĠvolÃ¡nÃŃ',
#  'Ġfeti',
#  'ĠÅ¡irÅ¡ÃŃ',
#  'ĠjarnÃŃ',
#  'Ġmikulov',
#  'Ġantibak',
#  'ĠpostavenÃŃ',
#  'ĠposkytovatelÅ¯',
#  'bujÃŃ',
#  'ĠtlouÅ¡Å¥',
#  'ĠcÃŃtil',
#  'Ġnaslou',
#  'ĠÅĻÃ¡dek',
#  'ĠvdanÃ©',
#  'ĠrozÅ¡ÃŃÅĻit',
#  'rozÃŃ',
#  'NapÅĻÃŃklad',
#  'ĠÃºloÅ¾iÅ¡tÄĽ',
#  'nony',
#  'Ġvytvo',
#  'Ġarcheolog',
#  'ĠnedÃ¡vnÃ©',
#  'ĠkrÃ©m',
#  'ĠzÃ¡stupcÅ¯',
#  'ĠpoÅ¡t',
#  'ĠFortu',
#  'ĠpÅĻednÃ¡Å¡ky',
#  'Ġmedaili',
#  'ĠMiroslav',
#  'stÅ¯m',
#  'ĠprÃŃ',
#  'kru',
#  'ĠÅ¾eleznice',
#  'pil',
#  'mati',
#  'bÃ¡t',
#  'tnov',
#  'ĠSnÃŃ',
#  'Ġspokojen',
#  'ĠzÃŃskÃ¡te',
#  'covÃ©',
#  'ĠvydÄĽlÃ¡',
#  'ĠstavÄĽ',
#  'NebankovnÃŃ',
#  'ĠÅ¾eb',
#  'ĠpouÅ¾ijte',
#  'ĠbezproblÃ©m',
#  'tika',
#  'Ġmajitel',
#  'ĠObÄįas',
#  'Ġnata',
#  'odol',
#  'ĠporozumÄĽt',
#  'ĠrovnÃ©',
#  'Ġpasi',
#  'ĠÅĻeÄįice',
#  'ĠÅ¾enatÃ½',
#  'Ġmozek',
#  'Ġspeciali',
#  'Ġnejroz',
#  'ĠZku',
#  'ĠnÃ½rsko',
#  'ĠdokonÄįit',
#  'mÄĽrnÃ¡',
#  'ĠrovinÄĽ',
#  'ĠnemusÃŃ',
#  'ĠhistorickÃ©',
#  'ĠÄįle',
#  'Ġkalo',
#  'letu',
#  'Ġfyzicky',
#  'ĠpÃ©ÄįÃŃ',
#  'Ġosa',
#  'ĠpÃŃsku',
#  'ĠÅ¡irokou',
#  'Å¾itek',
#  'dalo',
#  'ĠuklÃ¡dÃ¡nÃŃ',
#  'lze',
#  'ÅĻednÃŃ',
#  'videa',
#  'Ġtechnologii',
#  'Ġkina',
#  'ĠmÄĽÅĻit',
#  'ĠzÃ¡pad',
#  'Ġopilec',
#  'Ġ:-)Ċ',
#  'ÅĻnÃŃ',
#  'Ġmedu',
#  'ĠzaplatÃŃ',
#  'ĠsvÄĽtovÃ©',
#  'ĠanÃ¡lnÃŃho',
#  'Ġposti',
#  'akce',
#  'Ġtole',
#  'ĠÄįele',
#  'MyslÃŃm',
#  'ĠnemÃ¡m',
#  'poruje',
#  'ĠuklÃ¡dÃ¡',
#  'ĠnejnovÄĽjÅ¡ÃŃch',
#  'ĠOstrav',
#  'Ġope',
#  'ĠtroÅ¡ku',
#  'ĠstÄĽnÄĽ',
#  'Ġzob',
#  'Ġobnovy',
#  'ĠkrÃ¡sa',
#  'lici',
#  'ĠÅ¡am',
#  'ĠpÅĻedse',
#  'ĠchÅĻibskÃ¡',
#  'Ġligy',
#  'zemnÃŃ',
#  'Petr',
#  'Ġzouf',
#  'ĠvÄĽÅĻi',
#  'Ġkapacit',
#  'hlaste',
#  'Ãļvod',
#  'Ġnapa',
#  'ĠvyplÃ½',
#  'ĠmÄĽÅĻÃŃtku',
#  'tolog',
#  'ĠzÃ¡vratÄĽ',
#  'bÃŃzÃŃme',
#  'ovatelnÃ©',
#  'ĠmladÅ¡ÃŃch',
#  'Ġkach',
#  'ĠbazÃ©n',
#  'Ġsvobody',
#  'sivnÃŃ',
#  'ĠÃºdrÅ¾bu',
#  'Ġeti',
#  'ĠpartnerstvÃŃ',
#  'ĠkÅĻÃŃÅ¾',
#  'ĠdostateÄįnÄĽ',
#  'ĠVlÃ¡da',
#  'Ġnedodr',
#  'ĠklÃŃÄįe',
#  'ĠuÄįÃŃ',
#  'Ġmohelnice',
#  'Ġsehnat',
#  'Ġbudoucnosti',
#  'vÅ¯r',
#  'ĠnÃ¡vÅ¡tÄĽvnÃŃkÅ¯m',
#  'ĠmastnÃ½ch',
#  'plÅĪ',
#  'ĠnÄĽÄįem',
#  'Ġpotiskem',
#  'ĠnÄĽmeckÃ½',
#  'ĠodbÄĽ',
#  'ĠzatÃ¡',
#  'ĠjasnÄĽ',
#  'ĠmÃŃstnost',
#  'ĠÅ¾dÃ¡nice',
#  'ĠnÃ¡mÄĽ',
#  'ĠuvolnÄĽ',
#  'ĠbarvÄĽ',
#  'tÃ©ho',
#  'ĠkrÃ¡tkodobÃ¡',
#  'ĠpoÄįty',
#  'Ġkosmetiky',
#  'ĠvÅ¡eobec',
#  'Ġzpravodaj',
#  'ĠnepÅ¯j',
#  'dajÃŃcÃŃ',
#  'ĠVladi',
#  'Ġtvo',
#  'mnÄĽ',
#  'ĠdomÃ¡cnost',
#  'rÃ¡k',
#  'stil',
#  'Ġvysta',
#  'Ġmalin',
#  'vÃŃte',
#  'Ġteku',
#  'Ġnedo',
#  'itelnÃ½ch',
#  'ĠNakonec',
#  'Ġturna',
#  'ĠPotÅĻeb',
#  'Ġhistoricky',
#  'ĠdrÅ¾ÃŃ',
#  'kujte',
#  'ĠskvÄĽle',
#  'Ġsoupe',
#  'ĠdÄĽlal',
#  'Ġinovace',
#  'ĠzÃ¡pach',
#  'Ġseveru',
#  'JakÃ½',
#  'ĠÅĻÃŃÄįany',
#  'Ġturnaje',
#  'ĠvlastnostÃŃ',
#  'Ġnutnosti',
#  'stoupit',
#  'ĠsplÃ¡',
#  'ĠdolnÃŃ',
#  'JÃį',
#  'ĠnÃ¡la',
#  'Ġvyne',
#  'ĠvyÅ¾adovat',
#  'ymburk',
#  'ĠzvÃŃtÄĽ',
#  'ĠpatologiÃŃ',
#  'ĠmedicÃŃ',
#  'Ġvelvary',
#  'Ġtechnologiemi',
#  'ĠÄįtvrti',
#  'ĠostatnÃŃm',
#  'ĠFinanÄįnÃŃ',
#  'zÃ¡jem',
#  'ĠlÃ©ÄįivÃ©',
#  'ĠpouÅ¾ÃŃvanÃ©',
#  'Ġpokr',
#  'lovou',
#  'tÃ½',
#  'Ġreceptu',
#  'zdrav',
#  'ĠneplatÃŃ',
#  'ĠveÅĻejnÃ½',
#  'lÃŃku',
#  'mnÄĽli',
#  'ĠproblÃ©mÅ¯m',
#  'ĠslabÃ©',
#  'paÅĪ',
#  'ĠpoznÃ¡',
#  'Ġstolice',
#  'rcha',
#  'ĠvÃ¡Å¡eÅĪ',
#  'ĠtÄĽÅ¾kou',
#  'RÃ¡di',
#  'hrÃ¡l',
#  'ĠexternÃŃ',
#  'ĠpodrÃ¡Å¾',
#  'bran',
#  'ĠtkÃ¡nÄĽ',
#  'Ġkomise',
#  'ĠprokÃ¡zat',
#  'ĠbunÄĽk',
#  'ĠzaÄįaly',
#  'Ġnahradit',
#  'Rok',
#  'ĠneÄįekanÄĽ',
#  'ĠsvÄĽdky',
#  'ĠNynÃŃ',
#  'ĠÅ¾Ã¡dost',
#  'PÅĻeÄįtÄĽte',
#  'Ġjakoukoli',
#  'Å¡enÃ©',
#  'ĠrozmÄĽr',
#  'mentÃ¡lnÃŃ',
#  'ĠkrÃ¡lovÃ©',
#  'Ġhodo',
#  'NÃ¡zev',
#  'Ġsedmi',
#  'Ġpoci',
#  'ĠvytvoÅĻit',
#  'Ġkrav',
#  'Ã¡ÅĻÅ¯',
#  'ĠzboÅ¾ÃŃm',
#  'zovou',
#  'Ġsouprava',
#  'ĠpozdÄĽjÅ¡ÃŃ',
#  'ĠmanÅ¾elky',
#  'bÄĽÅ¾',
#  'ĠÄĮÃ¡st',
#  'ĠdopravnÃŃ',
#  'ĠinteligentnÃŃ',
#  'Ġhoupa',
#  'ĠovlÃ¡',
#  'ĠRÃ¡',
#  'Ġdetoxi',
#  'NejlepÅ¡ÃŃ',
#  'Ġvlivu',
#  'ĠÅ¡ÃŃÅĻku',
#  'pustit',
#  'Ġchud',
#  'ĠzjiÅ¡tÄĽ',
#  'ÅĻitom',
#  'Ġabnor',
#  'ĠdocÃŃ',
#  'nojmen',
#  'Ġnero',
#  'Ġrozpoznat',
#  'vaci',
#  'ĠkolÃ¡',
#  'ĠnÃ¡kladnÃŃ',
#  'poÄįtu',
#  'abÃ¡',
#  'Ġorgasmus',
#  'ĠdozvÄĽdÄĽt',
#  'ekÃ½n',
#  'havÄĽjÅ¡ÃŃ',
#  'krÃ¡',
#  'ĠÄįeskou',
#  'ĠsmÄĽs',
#  'ĠZadejte',
#  'ĠvÄĽkovÃ©',
#  'ĠdaÅĪovÃ©ho',
#  'Ġnemlu',
#  'Ġjistotu',
#  'rÃ¡Å¾ky',
#  'vÃ¡nÃŃm',
#  'ĠpeÄįi',
#  'ĠzasÃŃlÃ¡nÃŃ',
#  'ĠpouÅ¾ÃŃvÃ¡m',
#  'Ġsval',
#  'Ġautobusu',
#  'ĠdodÃ¡vajÃŃ',
#  'ĠzdÃ¡n',
#  'stitu',
#  'ÅĻÃŃÅ¾i',
#  'ssic',
#  'vii',
#  'Ġproduktem',
#  'ĠvÃ½le',
#  'ĠrÅ¯znÄĽ',
#  'ĠorlicÃŃ',
#  'ranit',
#  'Jednodu',
#  'Ġvyslov',
#  'veklov',
#  'rÃ¡la',
#  'aktivnÃŃ',
#  'minace',
#  'ĠvÄĽtÅĻnÃŃ',
#  'lÃŃk',
#  'ĠkÃ½m',
#  'leji',
#  'Ġvyvinut',
#  'Ġgastrointestin',
#  'ĠÅ¡patnÃ©',
#  'Ġbrada',
#  'ĠsezÃ³nu',
#  'ĠspolehlivÃ©',
#  'ĠsvÄĽdÄĽnÃŃ',
#  'ĠmodrÃ½',
#  'ĠrozmezÃŃ',
#  'Ġvyhodno',
#  'ĠdÄĽjin',
#  'Ġspravedl',
#  'ĠjelikoÅ¾',
#  'zovat',
#  'lovy',
#  'hlÃ©',
#  'ĠnÄĽme',
#  'ZajÃŃma',
#  'ĠsprÃ¡vnÃ½m',
#  'Ġpodpa',
#  'perskÃ©',
#  'ĠzdvojnÃ¡sob',
#  'Ġtlaku',
#  'nÃ¡cti',
#  'ĠpÅĻedpla',
#  'Å¾nicÃŃ',
#  'ĠdenÃŃku',
#  'ĠpoÅ¾ada',
#  'tÅĻeba',
#  'Ġuvi',
#  'ĠhvÄĽzdy',
#  'Ġroztr',
#  'ĠpÅĻihlÃ¡Å¡enÃŃ',
#  'Ġkolegy',
#  'ÄĮeskÃ½',
#  'Ġsymptomy',
#  'tiÅ¡tÄĽ',
#  'ĠvÃ½voji',
#  'ĠzaznamenÃ¡',
#  'Ġcidlinou',
#  'hereum',
#  'Å¾is',
#  'StÃ¡',
#  'Ġokraj',
#  'ĠpÅĻÃŃjemnou',
#  'Ġrakov',
#  'ĠzÅ¯stÃ¡vajÃŃ',
#  'Ġpochyb',
#  'ĠÄįeskosloven',
#  '.CZ',
#  'ĠÃºlo',
#  'Ġzima',
#  'ĠpÅĻesmÄĽ',
#  'ĠMusÃŃm',
#  'ĠjÃ¡t',
#  'utnat',
#  'ĠpÅĻechod',
#  'ĠÃºdrÅ¾',
#  'Å¡ÃŃnem',
#  'ĠÅ¡ortky',
#  'ĠzamÄĽÅĻena',
#  'louse',
#  'ĠodmÄĽnu',
#  'ĠinzerÃ¡ty',
#  'ĠuÅ¡ÃŃ',
#  'Ġporodu',
#  'ĠvÃŃkendu',
#  'ĠÄįesko',
#  'ĠvyspÄĽ',
#  'Ġvcelku',
#  'ĠÅĻidiÄįi',
#  'zÃŃm',
#  'dÄĽlÃ¡nÃŃ',
#  'ĠakorÃ¡t',
#  'ĠdÅ¯klad',
#  'ĠvÃ½bor',
#  'Ġposlan',
#  'Ġvelvy',
#  'Ġsezemice',
#  'Ġrobu',
#  'hotovo',
#  'ĠoseÄįnÃ¡',
#  'ĠÅ¾ehli',
#  'ĠÃºvodu',
#  'ĠpÅĻipravenÃ©',
#  'Ġsleduje',
#  'ĠUvi',
#  'ardnÃŃ',
#  'sÃ¡no',
#  'ĠduÅ¡evnÃŃ',
#  'ĠcviÄįenÃŃ',
#  'Ġdesku',
#  'fou',
#  'ĠinternetovÃ¡',
#  'ĠrozhodÄįÃŃ',
#  'Tyto',
#  'ĠuzavÅĻena',
#  'ĠpÃ¡rty',
#  'byla',
#  'jaku',
#  'ĠdÄĽdi',
#  'Ã³znÃŃ',
#  'Ġsnahy',
#  'anu',
#  'ĠTohle',
#  'ĠhanÃ©',
#  'kument',
#  'ĠsdÄĽli',
#  'ĠnezÃ¡',
#  'jetÃŃ',
#  'Ġsankce',
#  'Recenze',
#  'ĠBabi',
#  'datel',
#  'Å¡nÃ½ch',
#  'ĠÃºpravÄĽ',
#  'ĠzaloÅ¾enÃŃ',
#  'ĠÄįerst',
#  'tÃ¡ch',
#  'ĠZvÃ½',
#  'ckÃ©',
#  'lustraÄįnÃŃ',
#  'Ġprincipu',
#  ':|Ċ',
#  'Ġkno',
#  'nali',
#  'hledÃ¡nÃŃ',
#  'okup',
#  'Ġsucho',
#  ...]

# %%
#add the difference between vocabularies (creating union of the two vocabularies)
num_added_toks = old_tokenizer.add_tokens(new_tokens)

# %%
num_added_toks
# Out:
# 17017

# %%
print(len(old_tokenizer))
# Out:
# 145273

# %%
old_tokenizer.save_pretrained("models/Llama-3.2-3B-Instruct-cs_expanded")
# Out:
# ('models/Llama-3.2-3B-Instruct-cs_expanded/tokenizer_config.json',
#  'models/Llama-3.2-3B-Instruct-cs_expanded/special_tokens_map.json',
#  'models/Llama-3.2-3B-Instruct-cs_expanded/tokenizer.json')

# %% [markdown]
# ## Resize the Token embeddings

# %%
from transformers import PreTrainedTokenizer, PreTrainedTokenizerFast, PreTrainedModel
from typing import Union, Optional
import torch
from torch import nn

def resize_model_embeddings(model: PreTrainedModel,
                            old_tokenizer: Union[PreTrainedTokenizer, PreTrainedTokenizerFast], 
                            new_tokenizer:Union[PreTrainedTokenizer, PreTrainedTokenizerFast], 
                            type: Optional[str] = "mean_resizing"):
    assert type in ["mean_resizing", "subword_resizing", None]

    if type == "mean_resizing":
        #https://nlp.stanford.edu/~johnhew/vocab-expansion.html
        model.resize_token_embeddings(len(new_tokenizer), mean_resizing=True)
    elif type == "subword_resizing":
        #obtain original embeddings
        original_input_embeddings = model.get_input_embeddings()

        #get new tokens, ordered by ids
        new_tokens = list(set(new_tokenizer.get_vocab().keys()) - set(old_tokenizer.get_vocab().keys()))
        new_vocab = new_tokenizer.get_vocab()
        new_tokens = sorted(new_tokens, key=lambda x: new_vocab[x])
        
        #prepare new embeddings for extension
        added_embeddings = []
        for token in new_tokens:
            #get input ids in the original tokenizer
            input_ids = old_tokenizer.encode(token, add_special_tokens=False, return_tensors="pt")[0]

            #select corresponding embeddings from the original ones
            embeddings = original_input_embeddings(input_ids)
            #compute the mean
            mean_embedding = embeddings.mean(dim=0)

            #save the new embedding
            added_embeddings.append(mean_embedding)

        added_embeddings = torch.stack(added_embeddings).to(original_input_embeddings.weight.dtype)
        
        #prepare new embedding layer
        old_num_tokens, old_embedding_dim = original_input_embeddings.weight.shape

        new_num_tokens = old_num_tokens + added_embeddings.shape[0]
        new_embeddings = nn.Embedding(
                    new_num_tokens,
                    old_embedding_dim,
                    device=original_input_embeddings.weight.device,
                    dtype=original_input_embeddings.weight.dtype,
                )
        
        #copy the original embeddings
        new_embeddings.weight.data[:old_num_tokens] = original_input_embeddings.weight
        #initialize the new embeddings
        new_embeddings.weight.data[old_num_tokens:] = added_embeddings
        #set gradient requirement
        new_embeddings.requires_grad_(original_input_embeddings.weight.requires_grad)

        #set the new embeddings to the model
        model.set_input_embeddings(new_embeddings)

        #check if the model has tied weights in ouput layer
        if not model.config.get_text_config(decoder=True).tie_word_embeddings:
            raise ValueError("The model does not have tied weights in the output layer. This is currently not supported by the subword resizing.")
        
        vocab_size = model.get_input_embeddings().weight.shape[0]

        model.config.get_text_config().vocab_size = vocab_size
        model.vocab_size = vocab_size

        model.tie_weights()
        
    else:
        model.resize_token_embeddings(len(new_tokenizer), mean_resizing=False)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

old_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-3B-Instruct")
new_tokenizer = AutoTokenizer.from_pretrained("models/Llama-3.2-3B-Instruct-cs_expanded")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-3B-Instruct")

resize_model_embeddings(model, old_tokenizer, new_tokenizer, type="subword_resizing")
model
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ['Ġnasy', 'Ġvstupenky', 'ÅĻadu', 'Ġvce', 'teÄįnÃ½m', 'Ġdezer', 'ĠaÄį', 'ĠpÅĻedstaven', 'spod', 'ĠudÄĽlala', 'venÃŃ', 'ĠpÄĽknÄĽ', 'ĠdÃŃlny', 'hovÃ©', 'ĠDisku', 'ĠtÄĽÅ¾kÃ¡', 'ĠstÅĻihu', 'Ġpum', 'ĠsouÄįasnÄĽ', 'ĠdobrÃ½m', '|Hmotnost', 'Ġkoru', 'Ġosoba', 'Ġspustit', 'ĠÄįernÃ½ch', 'ĠsfÃ©', 'manÅ¯v', 'Ġrytmu', 'Å¾Ã¡d', 'fikovanÃ©', 'ĠÃºplnÃ©', 'VÃŃce', 'ĠvÄĽnovat', 'ĠprotÃ¡', 'Ġkonzu', 'Ġkoleg', 'Ġmaleb', 'Ġkonstrukce', 'ĠslouÄįen', 'ĠpraktickÃ½ch', 'HlavnÃŃ', 'ĠNedo', 'ĠnÃ¡poj', 'ntÃ¡l', 'nejlepÅ¡ÃŃ', 'Ġnejmlad', 'tina', 'ĠMys', 'ĠnevÃ¡', 'ĠprÃŃjmu', 'uret', 'ĠpodnikatelskÃ©', 'ĠexistujÃŃ', 'ĠmÅ¯Å¾ou', 'ĠÅ¾ijÃŃcÃŃ', 'ĠTereza', 'Å¾uje', 'ĠjÃŃdlo', 'ramek', 'ĠvÅ¯nÄĽ', 'ĠnÃ¡vÅ¡tÄĽva', 'ĠmodernÃŃch', 'ĠdÅ¯sledku', 'ovanÃ½m', 'Å½i', 'Ġpodpis', 'hlo', 'Ġpasu', 'ĠzÃ¡ru', 'ĠvÃ½sledkÅ¯', 'Ġpotravin', 'Äįany', 'riginÃ¡lnÃŃ', 'Ġjednomu', 'ÅĪujÃŃcÃŃ', 'ĠspadÃ¡', 'ĠpouliÄįnÃŃ', 'Ġsvita', 'Ġletovice', 'ĠÄįela', 'chne', 'nickou', 'Ġrozli', 'ĠodhalÃŃ', 'ĠDÃ¡n', 'Ġmamin', 'ĠobhÃ¡', 'ĠpÅĻejÃŃ', 'anis', 'ĠzÃ¡vislost', 'ĠsmÄĽsi', 'cena', 'Ġingredience', 'Ġsra', 'liber', 'ĠskrytÃ¡', 'ĠdozvÄĽ', 'ĠvÃ½Å¡ky', 'ĠtÄĽÅ¡ÃŃm', 'Ġrezon', 'ĠreÅ¾isÃ©ra', 'ĠnoÅ¾', 'ĠveÄįÃŃ', 'ĠuhlÃŃ', 'kupe', 'vodce', 'doba', 'Kou', 'ĠtÃ©mata', 'Ġzisk', 'ĠKrista', 'ĠkrevnÃŃ', 'osice', 'ĠvyuÅ¾ili', 'Ġpodzi', 'livÃ½m', 'ĠsÃŃdla', 'ĠpodobnÃ©', 'ĠmodrÃ¡', 'ĠsvÄĽdÄįÃŃ', 'itÃ½m', 'ĠmanÅ¾elem', 'ĠodpoÄįinku', 'LAD', 'UDr', 'varu', 'VÅ¡ech', 'roh', 'dÄĽlala', 'ĠpatnÃ¡ct', 'ĠztrÃ¡', 'Ġplnit', 'ĠchemickÃ©', 'ĠhospodÃ¡ÅĻstvÃŃ', 'Ġpotraviny', 'ĠprodÃ¡vajÃŃcÃŃ', 'ĠotÄĽ', 'tinÄĽ', 'lnÄĽ', 'ĠchlupatÃ¡', 'ĠdomÃ¡cÃŃm', 'ĠPomo', 'ĠbojÃŃ', 'Ġose', 'vinÃ¡', 'nÄĽnÃŃm', 'Ġdopis', 'Ġtitu', 'peme', 'ĠmnÃŃÅ¡ek', 'Ġdvo', 'povÄĽdÄĽt', 'OVÃĿ', 'ĠmÄĽÅĻÃŃ', 'tud', 'Ġpokles', 'ĠÄįokolÃ¡dy', 'pÄĽ', 'skem', 'ĠzÃ¡jmÅ¯', 'Ġlednice', 'Ġosmi', 'ĠnÃ¡vrhy', 'ĠÅĻeditele', 'ĠDomÃ¡cÃŃ', 'dejte', 'ĠportrÃ©', 'Ġpohon', 'ĠletiÅ¡tÄĽ', 'Ġjednalo', 'Ġmapu', 'ĠfunkÄįnÃŃ', 'ĠpÅĻedstavenÃŃ', 'Ġpoch', 'ĠzÃ¡da', 'Ġtypem', 'Å¯Å¾ete', 'ĠtÃ©ma', 'Ġasistent', 'Ġhni', 'Ġprezentaci', 'ĠAÅ¾', 'Ġporucha', 'ĠzÃ¡vodÅ¯', 'Ġkapky', 'ĠuvnitÅĻ', 'ĠÅ¡etr', 'bÃ¡n', 'ĠvidÃŃm', 'Ġpotre', 'Ġnutnost', 'Ġvyme', 'ĠhÃ½', 'ĠuloÅ¾it', 'ĠobÄįanÅ¯', 'Ġtrochou', 'ĠzvyÅ¡ujÃŃ', 'ZÃŃ', 'ĠpÅĻestup', 'ĠPÃŃs', 'kovÃ½mi', 'ĠSenÃ¡tu', 'prostÅĻed', 'Ġbys', 'ĠlogickÃ©', 'jmenÅ¡ÃŃm', 'dÄĽzem', 'teru', 'ĠnahoÅĻe', 'ĠvypadÃ¡', 'ĠosobnÄĽ', 'Ġnaviga', 'ĠmezinÃ¡rodnÃŃho', 'ĠStarÃ©', 'Ġpleve', 'ĠzvÃŃÅĻecÃŃ', 'vÅ¡ÃŃ', 'ĠnedÃ¡', 'ĠovÄĽÅĻit', 'ĠsezÃ³', 'ĠplatbÄĽ', 'ĠpÄĽstovat', 'ĠprohlÃŃÅ¾e', 'Ġchatu', 'Ġoslavy', 'ĠtakovÃ©ho', 'movÃ¡', 'ĠÅ¡krÃ¡', 'Ġkontextu', 'ĠspeciÃ¡lnÃŃ', 'ĠchyÅ¡e', 'ĠjednoduchÃ½', 'ĠUkÃ¡', 'zvlÃ¡', 'ĠdÃ¡m', 'ĠBeroun', 'Ġnovinku', 'ĠÅ¡vihov', 'ĠprÅ¯vod', 'ĠvzpomÃŃ', 'ĠpÅĻÃŃpadÅ¯', 'ĠbÅĻeznu', 'antnÃŃ', 'ĠnÅ¯Å¾', 'lakt', 'ĠhubnutÃŃ', 'ĠrodiÄįÅ¯m', 'ovci', '?âĢľĊ', 'vaceti', 'ĠÅ¡enov', 'ÄįÃŃme', 'Ġodstart', 'Kla', 'ĠerotickÃ¡', 'ĠvÃ½jimky', 'Dva', 'ĠbateriÃŃ', 'ĠstÅ¯l', 'ĠStÃ¡', 'bliÅ¾Å¡ÃŃ', 'ĠhoÅĻe', 'Ġcasinu', 'ĠpochÃ¡zÃŃ', 'ĠkÄį', 'Ġnemohla', 'ĠmasÃ¡', 'zetÃŃ', 'kvi', 'ĠpÅĻevÃ¡', 'ĠdÅ¯chodu', 'ĠnemÅ¯Å¾u', 'ĠdÃ½ch', 'Ġnahoru', 'ĠhranÃŃ', 'ĠJaroslava', 'dÃ¡m', 'ĠvÃ½Å¾ivu', 'Ġkamene', 'Ġstrava', 'Ġhluboko', 'Ġkonal', 'ĠbudoucÃŃch', 'ntry', 'prosto', 'hemale', 'ĠkomentÃ¡ÅĻÅ¯', 'ĠobrÃ¡zkÅ¯', 'vÄĽtÅ¡ÃŃm', 'ĠvzÃ¡c', 'ĠObjednÃ¡', 'ĠpoptÃ¡vka', 'Ġoni', 'PomocÃŃ', 'ĠNÃ¡slednÄĽ', 'ĠlÃ¡sce', 'ĠUkrajiny', 'ĠvystÅĻÃŃ', 'ĠstarostÃŃ', 'Ġzarago', 'ĠgramÅ¯', 'ĠkamarÃ¡di', 'Ġinvesti', 'ĠrobustnÃŃ', 'kÃ¡lnÃŃ', 'Ġzimu', 'kula', 'tavou', 'Firma', 'rÅ¯v', 'Ġautomobilu', 'ĠzÃŃ', 'ĠProblÃ©m', 'Ġprona', 'Ġkerami', 'kovÃ¡ny', 'Ġstanou', 'SouÄįÃ¡stÃŃ', 'uÅ¾', 'pomÃŃ', 'ĠlaboratoÅĻe', 'ĠnepatÅĻÃŃ', 'Ġvalen', 'ĠurÄįenÃ½ch', 'ĠstrÃ¡nce', 'ĠverzÃŃ', 'Ġvyho', 'ĠnÃŃzko', 'Ġmotivace', 'ĠLucie', 'bÃ½vÃ¡', 'ĠÄįelÃŃ', 'ĠsuÅ¡enÃŃ', 'Å¯vodnÃŃ', 'ĠdesÃ¡t', 'Ġmarketingu', 'ĠvyplatÃŃ', 'Ġkomor', 'ĠiPhonu', 'ĠmanuÃ¡lnÃŃ', 'ĠuzavÅĻenÃŃ', 'jsou', 'Ġkoupila', 'Ġtechnika', 'ĠveterÃ¡', 'vacÃŃho', 'kovy', 'Ġusil', 'ĠvedenÃŃm', 'Ġzasa', 'Ġskladem', 'ĠÄĮEZ', 'ĠKlepnÄĽte', 'ĠlhÅ¯ty', 'Ġproslu', 'Ġodkaz', 'tkov', ...
# [128256, 128257, 128258, 128259, 128260, 128261, 128262, 128263, 128264, 128265, 128266, 128267, 128268, 128269, 128270, 128271, 128272, 128273, 128274, 128275, 128276, 128277, 128278, 128279, 128280, 128281, 128282, 128283, 128284, 128285, 128286, 128287, 128288, 128289, 128290, 128291, 128292, 128293, 128294, 128295, 128296, 128297, 128298, 128299, 128300, 128301, 128302, 128303, 128304, 128305, 128306, 128307, 128308, 128309, 128310, 128311, 128312, 128313, 128314, 128315, 128316, 128317, 128318, 128319, 128320, 128321, 128322, 128323, 128324, 128325, 128326, 128327, 128328, 128329, 128330, 128331, 128332, 128333, 128334, 128335, 128336, 128337, 128338, 128339, 128340, 128341, 128342, 128343, 128344, 128345, 128346, 128347, 128348, 128349, 128350, 128351, 128352, 128353, 128354, 128355, 128356, 128357, 128358, 128359, 128360, 128361, 128362, 128363, 128364, 128365, 128366, 128367, 128368, 128369, 128370, 128371, 128372, 128373, 128374, 128375, 128376, 128377, 128378, 128379, 128380, 128381, 128382, 128383, 128384, 128385, 128386, 128387, 128388, 128389, 128390, 128391, 128392, 128393, 128394, 128395, 128396, 128397, 128398, 128399, 128400, 128401, 128402, 128403, 128404, 128405, 128406, 128407, 128408, 128409, 128410, 128411, 128412, 128413, 128414, 128415, 128416, 128417, 128418, 128419, 128420, 128421, 128422, 128423, 128424, 128425, 128426, 128427, 128428, 128429, 128430, 128431, 128432, 128433, 128434, 128435, 128436, 128437, 128438, 128439, 128440, 128441, 128442, 128443, 128444, 128445, 128446, 128447, 128448, 128449, 128450, 128451, 128452, 128453, 128454, 128455, 128456, 128457, 128458, 128459, 128460, 128461, 128462, 128463, 128464, 128465, 128466, 128467, 128468, 128469, 128470, 128471, 128472, 128473, 128474, 128475, 128476, 128477, 128478, 128479, 128480, 128481, 128482, 128483, 128484, 128485, 128486, 128487, 128488, 128489, 128490, 128491, 128492, 128493, 128494, 128495, 128496, 128497, 128498, 128499, 128500, 128501, 128502, 128503, 128504, 128505, 128506, 128507, 128508, 128509, 128510, 128511, 128512, 128513, 128514, 128515, 128516, 128517, 128518, 128519, 128520, 128521, 128522, 128523, 128524, 128525, 128526, 128527, 128528, 128529, 128530, 128531, 128532, 128533, 128534, 128535, 128536, 128537, 128538, 128539, 128540, 128541, 128542, 128543, 128544, 128545, 128546, 128547, 128548, 128549, 128550, 128551, 128552, 128553, 128554, 128555, 128556, 128557, 128558, 128559, 128560, 128561, 128562, 128563, 128564, 128565, 128566, 128567, 128568, 128569, 128570, 128571, 128572, 128573, 128574, 128575, 128576, 128577, 128578, 128579, 128580, 128581, 128582, 128583, 128584, 128585, 128586, 128587, 128588, 128589, 128590, 128591, 128592, 128593, 128594, 128595, 128596, 128597, 128598, 128599, 128600, 128601, 128602, 128603, 128604, 128605, 128606, 128607, 128608, 128609, 128610, 128611, 128612, 128613, 128614, 128615, 128616, 128617, 128618, 128619, 128620, 128621, 128622, 128623, 128624, 128625, 128626, 128627, 128628, 128629, 128630, 128631, 128632, 128633, 128634, 128635, 128636, 128637, 128638, 128639, 128640, 128641, 128642, 128643, 128644, 128645, 128646, 128647, 128648, 128649, 128650, 128651, 128652, 128653, 128654, 128655, 128656, 128657, 128658, 128659, 128660, 128661, 128662, 128663, 128664, 128665, 128666, 128667, 128668, 128669, 128670, 128671, 128672, 128673, 128674, 128675, 128676, 128677, 128678, 128679, 128680, 128681, 128682, 128683, 128684, 128685, 128686, 128687, 128688, 128689, 128690, 128691, 128692, 128693, 128694, 128695, 128696, 128697, 128698, 128699, 128700, 128701, 128702, 128703, 128704, 128705, 128706, 128707, 128708, 128709, 128710, 128711, 128712, 128713, 128714, 128715, 128716, 128717, 128718, 128719, 128720, 128721, 128722, 128723, 128724, 128725, 128726, 128727, 128728, 128729, 128730, 128731, 128732, 128733, 128734, 128735, 128736, 128737, 128738, 128739, 128740, 128741, 128742, 128743, 128744, 128745, 128746, 128747, 128748, 128749, 128750, 128751, 128752, 128753, 128754, 128755, ...
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(145273, 3072)
#     (layers): ModuleList(
#       (0-27): 28 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=3072, out_features=8192, bias=False)
#           (up_proj): Linear(in_features=3072, out_features=8192, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=3072, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((3072,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=145273, bias=False)
# )
